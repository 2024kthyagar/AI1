# %% [markdown]
# # Imports

# %%
#Basic imports
import numpy as np
import pandas as pd

#sklearn imports
from sklearn.decomposition import PCA #Principal Component Analysis
from sklearn.manifold import TSNE #T-Distributed Stochastic Neighbor Embedding
from sklearn.cluster import KMeans #K-Means Clustering
from sklearn.preprocessing import StandardScaler #used for 'Feature Scaling'

#plotly imports
import plotly as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %% [markdown]
# # Read the Data

# %%
df = pd.read_csv('optdigits.csv')
df
# Out:
#       Dim1  Dim2  Dim3  Dim4  Dim5  Dim6  Dim7  Dim8  Dim9  Dim10  ...  Dim56  \
# 0        0     1     6    15    12     1     0     0     0      7  ...      0
# 1        0     0    10    16     6     0     0     0     0      7  ...      0
# 2        0     0     8    15    16    13     0     0     0      1  ...      0
# 3        0     0     0     3    11    16     0     0     0      0  ...      0
# 4        0     0     5    14     4     0     0     0     0      0  ...      0
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...    ...
# 3818     0     0     5    13    11     2     0     0     0      2  ...      0
# 3819     0     0     0     1    12     1     0     0     0      0  ...      0
# 3820     0     0     3    15     0     0     0     0     0      0  ...      0
# 3821     0     0     6    16     2     0     0     0     0      0  ...      0
# 3822     0     0     2    15    16    13     1     0     0      0  ...      0
#
#       Dim57  Dim58  Dim59  Dim60  Dim61  Dim62  Dim63  Dim64  Class
# 0         0      0      6     14      7      1      0      0      0
# 1         0      0     10     16     15      3      0      0      0
# 2         0      0      9     14      0      0      0      0      7
# 3         0      0      0      1     15      2      0      0      4
# 4         0      0      4     12     14      7      0      0      6
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...
# 3818      0      0      8     13     15     10      1      0      9
# 3819      0      0      0      4      9      0      0      0      4
# 3820      0      0      4     14     16      9      0      0      6
# 3821      0      0      5     16     16     16      5      0      6
# 3822      0      0      4     14      1      0      0      0      7
#
# [3823 rows x 65 columns]

# %% [markdown]
# # Train the Model

# %%
#Initialize our model
kmeans = KMeans(n_clusters=10)

# %%
#Fit our model
kmeans.fit(df)
# Out:
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# KMeans(n_clusters=10)

# %%
#Find which cluster each data-point belongs to
clusters = kmeans.predict(df)
# Out:
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.

# %%
#Add the cluster vector to our DataFrame, X
df["Cluster"] = clusters

# %% [markdown]
# # Visualization Using PCA

# %%
#plotX is a DataFrame containing 5000 values sampled randomly from X
# need to take a stratified random sample
plotX = df

# %%
#Rename plotX's columns since it was briefly converted to an np.array above
# plotX.columns = X.columns

# %%
#PCA with one principal component
pca_1d = PCA(n_components=1)

#PCA with two principal components
pca_2d = PCA(n_components=2)

#PCA with three principal components
pca_3d = PCA(n_components=3)

# %%
#This DataFrame holds that single principal component mentioned above
PCs_1d = pd.DataFrame(pca_1d.fit_transform(plotX.drop(["Cluster"], axis=1)))

#This DataFrame contains the two principal components that will be used
#for the 2-D visualization mentioned above
PCs_2d = pd.DataFrame(pca_2d.fit_transform(plotX.drop(["Cluster"], axis=1)))

#And this DataFrame contains three principal components that will aid us
#in visualizing our clusters in 3-D
PCs_3d = pd.DataFrame(pca_3d.fit_transform(plotX.drop(["Cluster"], axis=1)))
# Out:
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.

# %%
PCs_1d.columns = ["PC1_1d"]

#"PC1_2d" means: 'The first principal component of the components created for 2-D visualization, by PCA.'
#And "PC2_2d" means: 'The second principal component of the components created for 2-D visualization, by PCA.'
PCs_2d.columns = ["PC1_2d", "PC2_2d"]

PCs_3d.columns = ["PC1_3d", "PC2_3d", "PC3_3d"]

# %%
plotX = pd.concat([plotX,PCs_1d,PCs_2d,PCs_3d], axis=1, join='inner')

# %%
plotX["dummy"] = 0

# %%
#Note that all of the DataFrames below are sub-DataFrames of 'plotX'.
#This is because we intend to plot the values contained within each of these DataFrames.

cluster0 = plotX[plotX["Cluster"] == 0]
cluster1 = plotX[plotX["Cluster"] == 1]
cluster2 = plotX[plotX["Cluster"] == 2]
cluster3 = plotX[plotX["Cluster"] == 3]
cluster4 = plotX[plotX["Cluster"] == 4]
cluster5 = plotX[plotX["Cluster"] == 5]
cluster6 = plotX[plotX["Cluster"] == 6]
cluster7 = plotX[plotX["Cluster"] == 7]
cluster8 = plotX[plotX["Cluster"] == 8]
cluster9 = plotX[plotX["Cluster"] == 9]

# %%
#This is needed so we can display plotly plots properly
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
pip install nbformat
# Out:
# Requirement already satisfied: nbformat in /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages (5.9.2)
# Requirement already satisfied: fastjsonschema in /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages (from nbformat) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages (from nbformat) (4.20.0)
# Requirement already satisfied: jupyter-core in /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages (from nbformat) (5.5.0)
# Requirement already satisfied: traitlets>=5.1 in /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages (from nbformat) (5.14.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat) (0.16.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages (from jupyter-core->nbformat) (4.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#trace1 is for 'Cluster 0'
trace1 = go.Scatter(
                    x = cluster0["PC1_1d"],
                    y = cluster0["dummy"],
                    mode = "markers",
                    name = "Cluster 0",
                    marker = dict(color = 'rgba(255, 128, 255, 0.8)'),
                    text = None)

#trace2 is for 'Cluster 1'
trace2 = go.Scatter(
                    x = cluster1["PC1_1d"],
                    y = cluster1["dummy"],
                    mode = "markers",
                    name = "Cluster 1",
                    marker = dict(color = 'rgba(255, 128, 2, 0.8)'),
                    text = None)

#trace3 is for 'Cluster 2'
trace3 = go.Scatter(
                    x = cluster2["PC1_1d"],
                    y = cluster2["dummy"],
                    mode = "markers",
                    name = "Cluster 2",
                    marker = dict(color = 'rgba(0, 255, 200, 0.8)'),
                    text = None)

data = [trace1, trace2, trace3]

title = "Visualizing Clusters in One Dimension Using PCA"

layout = dict(title = title,
              xaxis= dict(title= 'PC1',ticklen= 5,zeroline= False),
              yaxis= dict(title= '',ticklen= 5,zeroline= False)
             )

fig = dict(data = data, layout = layout)

iplot(fig)
# Out:
# <div>                            <div id="67df5618-1e3d-4a73-8aa9-92152961b13c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("67df5618-1e3d-4a73-8aa9-92152961b13c")) {                    Plotly.newPlot(                        "67df5618-1e3d-4a73-8aa9-92152961b13c",                        [{"marker":{"color":"rgba(255, 128, 255, 0.8)"},"mode":"markers","name":"Cluster 0","x":[-19.08065395066317,-24.330622970526928,-29.45116576057831,-25.36671509640025,-19.31624747631892,-27.240894081417345,-18.281149386692796,-21.0357350186403,-19.04165114842781,-23.14617570465102,-19.94143049239106,-13.439517105973072,-19.03322171009924,-24.434382281382337,-27.223704183786648,-15.476598082114586,-26.092194665404257,-22.761270221841254,-23.534371920059527,-25.512333871146325,-13.729035088711258,-12.06543381631043,-19.600728624044404,-22.803150720848762,-14.040138826137843,-16.428001669666212,-22.521723736327118,-15.616076579493685,-18.751939622144196,-14.934327260140593,-14.801725197900101,-23.921945029277097,-22.681859452146398,-20.674906219203855,-16.157501414983862,-22.351425582757972,-22.096537489071178,-12.01639536872191,-20.785792392510206,-24.535368512269702,
480537,-23.613511307658207,-16.844988016210653,-22.524289493935893,-22.682354311973167,-28.66474360676135,-21.68704835126188,-28.944645659047954,-14.94032394294119,-24.118003787637516,-23.065452727131074,-17.159600314999047,-19.740453058657845,-25.648753632330617,-27.6482289310111,-21.70655318048778,-24.568282044842217,-20.31021612515142,-19.681717918379263,-19.791637582940037,-21.33055767187356,-19.188077794541602,-16.146306313993886,-20.943481548462138,-11.415232579482963,-19.054145622194213,-23.47190238833596,-21.645669943777907,-21.396476106039447,-17.14296715558109,-13.653024580456586,-4.442185381658641,-20.566460944763044,-19.024547460442744,-12.864612734204622,-16.104845890135763,-17.398439959286133,-10.675797013358594,-24.54902390332374,-12.052313785947119,-11.054257434791841,-16.833015333034098,-20.612285192216113,-22.20831118478603,-20.932924512825107 ...

# %% [markdown]
# # Performance

# %%
print(kmeans.inertia_) # sklearn built in sse metric
# Out:
# 2491510.749142049

# %%
df.head()
# Out:
#    Dim1  Dim2  Dim3  Dim4  Dim5  Dim6  Dim7  Dim8  Dim9  Dim10  ...  Dim57  \
# 0     0     1     6    15    12     1     0     0     0      7  ...      0
# 1     0     0    10    16     6     0     0     0     0      7  ...      0
# 2     0     0     8    15    16    13     0     0     0      1  ...      0
# 3     0     0     0     3    11    16     0     0     0      0  ...      0
# 4     0     0     5    14     4     0     0     0     0      0  ...      0
#
#    Dim58  Dim59  Dim60  Dim61  Dim62  Dim63  Dim64  Class  Cluster
# 0      0      6     14      7      1      0      0      0        3
# 1      0     10     16     15      3      0      0      0        3
# 2      0      9     14      0      0      0      0      7        0
# 3      0      0      1     15      2      0      0      4        6
# 4      0      4     12     14      7      0      0      6        2
#
# [5 rows x 66 columns]

# %%
import numpy as np

# Check for NaN values
print(np.isnan(df).any())

# Check for infinite values
print(np.isinf(df).any())
# Out:
# Dim1       False
# Dim2       False
# Dim3       False
# Dim4       False
# Dim5       False
#            ...
# Dim62      False
# Dim63      False
# Dim64      False
# Class      False
# Cluster    False
# Length: 66, dtype: bool
# Dim1       False
# Dim2       False
# Dim3       False
# Dim4       False
# Dim5       False
#            ...
# Dim62      False
# Dim63      False
# Dim64      False
# Class      False
# Cluster    False
# Length: 66, dtype: bool

# %%
# silhoutte score 
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

# sample = pd.DataFrame(np.array(X.sample(5000)))

for n_clusters in range(4, 12):
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(df)
    centers = clusterer.cluster_centers_
    # print('here')
    score = silhouette_score(df, preds)
    print("For n_clusters = {}, silhouette score is {})".format(n_clusters, score))
# print(silhoutte_score(X, ))
# Out:
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# For n_clusters = 4, silhouette score is 0.13904812418313017)
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# For n_clusters = 5, silhouette score is 0.15125146363169373)
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# For n_clusters = 6, silhouette score is 0.16507843123079105)
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# For n_clusters = 7, silhouette score is 0.17550311058677615)
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# For n_clusters = 8, silhouette score is 0.18541142765949684)
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# For n_clusters = 9, silhouette score is 0.19342638777584786)
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# For n_clusters = 10, silhouette score is 0.197751373681145)
# For n_clusters = 11, silhouette score is 0.19469965758586602)
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:757: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:595: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#
# /Users/ryandpark/miniconda3/envs/py311/lib/python3.11/site-packages/sklearn/utils/validation.py:604: FutureWarning:
#
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.

# %%
df['Cluster'].value_counts()
# Out:
# Cluster
# 1    720
# 9    444
# 4    385
# 8    380
# 0    373
# 5    353
# 7    310
# 6    303
# 3    291
# 2    264
# Name: count, dtype: int64

# %%
accuracy = 0
for i in range(len(df)):
    if df.loc[i]['Cluster'] == df.loc[i]['Class']:
        accuracy += 1
print(accuracy / len(df))
# Out:
# 0.19513471095997909

# %% [markdown]
# silhoutte score for values of k 2-8 are poor
